# %%
# Abhängigkeiten installieren
#!pip install yfinance pandas numpy matplotlib scikit-learn tensorflow statsmodels hmmlearn pyarrow papermill

# Zum Updaten von yfinance:
#!pip install --upgrade yfinance
